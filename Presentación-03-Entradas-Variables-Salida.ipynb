# %% [markdown]
# **Declarar una variable**

# %%
edad = 17

# %% [markdown]
# **Declarar una variable e imprimir su valor**

# %%
edad = 17
print(edad)
# Out:
# 17

# %% [markdown]
# **Declarar una variable y acceder mal a ella**

# %%
edad = 17
print(edadd)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2438eff43c21> in <module>()
#       1 edad = 17
# ----> 2 print(edadd)
#
# NameError: name 'edadd' is not defined

# %% [markdown]
# **Declarar diferentes tipos de variables**

# %%
nombre = "Maria"
edad = 17
estatura = 1.60

# %% [markdown]
# **Declarar e imprimir diferentes tipos de variables**

# %%
nombre = "Maria"
edad = 17
estatura = 1.60

print(estatura)
print(nombre)
print(edad)

# %% [markdown]
# **Declarar y modificar valor de variables**

# %%
precioProducto = 150
print(precioProducto)

precioProducto = 250
print(precioProducto)

# %% [markdown]
# **Declarar y modificar el valor y tipo de variables**

# %%
precioProducto = 150
print(precioProducto)

precioProducto = 250.5
print(precioProducto)

# %% [markdown]
# **Utilizar la función *type()* para verificar el tipo de las variables**

# %%
precioProducto = 150
print(type(precioProducto))

precioProducto = 250.5
print(type(precioProducto))

# %% [markdown]
# **Reutilizar el valor de variables para crear nuevas variables**

# %%
misAhorros = 100
susAhorros = 150
ahorrosTotales = misAhorros + susAhorros
promedioAhorroPorPersona = ahorrosTotales/2

print(ahorrosTotales)
print(promedioAhorroPorPersona)

# %% [markdown]
# **Ejercicio 1**

# %%
edadRichard = 71
edadJeff = 58
edadElon = 50

promedio = (edadRichard + edadJeff + edadElon)/3
print(promedio)

# %% [markdown]
# **Utilizar la función *input()* para recoger datos del teclado**

# %%
print("Ingrese su nombre:")
nombre = input()
print("Su nombre es:")
print(nombre)

# %% [markdown]
# **La función *input()* devuelve un *str*:**

# %%
edad = input("Ingrese su edad: ")
print("Su edad es:")
print(edad)
mitadDeEdad = edad/2
print(mitadDeEdad)

# %% [markdown]
# **Conviertiendo el tipo que devuelve *input()* a *int*:**

# %%
edad = int(input("Ingrese su edad: "))
print("Su edad es:")
print(edad)
mitadDeEdad = edad/2
print("Su mitad de edad es:")
print(mitadDeEdad)

# %% [markdown]
# **Definiendo variables con *input()* con y sin conversión:**

# %%
edadPadre = input("Ingrese edad: ")
edadMadre = int(input("Ingrese edad: "))

# %% [markdown]
# **Ejercicio 2**

# %%
nombre = input("Ingrese nombre: ")
edad = int(input("Ingrese edad: "))
estatura = float(input("Ingrese estatura: "))

misDatos = nombre + " - " + str(edad) + " - " + str(estatura)

print(misDatos)

# %% [markdown]
# **Utilizando la función *input()* para imprimir variables y textos**

# %%
nombre = "Maria"
edad = 17

print("Nombre: ")
print(nombre)
print("Edad: ")
print(edad)

# %% [markdown]
# **Concatenando mal textos y variables**

# %%
nombre = "Maria"
edad = 17

print("Nombre: "+nombre)
print("Edad: "+edad)

# %% [markdown]
# **Concatenando bien textos y variables**

# %%
nombre = "Maria"
edad = 17

print("Nombre: "+nombre)
print("Edad: "+str(edad))

# %% [markdown]
# **Ejercicio final**

# %%
nombre1 = input("Ingrese nombre: ")
estatura1 = float(input("Ingrese estatura: "))

nombre2 = "Luis"
estatura2 = 1.68
estatura2 = 1.70

print("Nombre1: "+nombre1)
print("Estatura1: "+str(estatura1))
print("nombre2: "+nombre2)
print("Estatura2: "+str(estatura2))

promedioEstaturas = (estatura1+estatura2)/2

print("Promedio estaturas: "+str(promedioEstaturas))
